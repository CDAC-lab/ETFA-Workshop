# %% [markdown]
# <a href="https://colab.research.google.com/github/CDAC-lab/ETFA-Workshop/blob/main/Long_Short_Term_Memory_Networks_for_Energy_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Long Short Term Memory Networks for Sequential Data Analysis - Energy Consumption Forecasting
#
# In this tutorial we will conduct energy consumption forecasting using a Recurrent Neural Network.
#
# **Dataset:**
# The  dataset is from the La Trobe University Energy Analytics Platform (LEAP), the Net Zero initiative at La Trobe. The dataset contains energy consumption
# readings (MeterReading column) of a teaching building at 1-hour time intervals.

# %% [markdown]
# ## Load Libraries
#
# Load required libraries for modeling and data processing

# %%
# %tensorflow_version 1.x
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU
from keras.callbacks import ModelCheckpoint
from matplotlib.dates import DateFormatter
# %matplotlib inline

# %% [markdown]
# ## Load data from google drive
#
# Libraries to load data from google drive shared location.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Authenticate and create the python document (PyDrive) client.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# When prompted, click on the link to get authentication to allow Google to access your Drive. You should see a screen with “Google Cloud SDK wants to access your Google Account” at the top. After you allow permission, copy the given verification code and paste it in the box in Colab.

# %%
dataset_file_id = '1X42C-CLgn06m5c4NksutyKe87jZseFNk'

# %% [markdown]
# Download the dataset file.

# %%
downloaded = drive.CreateFile({'id':dataset_file_id}) 
downloaded.GetContentFile('building_type_teaching_ts.csv')

# %% [markdown]
# Load the dataset file to a dataframe using Pandas library.

# %%
df = pd.read_csv('building_type_teaching_ts.csv', index_col=0)

# %% [markdown]
# Explore the dataset.

# %%
df.head(10)
# Out:
#                      MeterReading
# Timestamp
# 2018-01-01 00:00:00        21.532
# 2018-01-01 01:00:00        28.625
# 2018-01-01 02:00:00        28.937
# 2018-01-01 03:00:00        28.688
# 2018-01-01 04:00:00        29.531
# 2018-01-01 05:00:00        28.875
# 2018-01-01 06:00:00        27.562
# 2018-01-01 07:00:00        50.437
# 2018-01-01 08:00:00        57.656
# 2018-01-01 09:00:00        57.594

# %% [markdown]
# Dataset contains 2 column:
#
#
# 1.   Timestamp
# 2.   MeterReading (Our predictor)

# %% [markdown]
# ## Preprocessing
#
# We will conduct 2 pre-processing steps for this dataset,
# 1. Normalize the dataset
# 2. Format the dataset to adapt recurrent learning.

# %% [markdown]
# ### Standardization

# %% [markdown]
# Copy the index (i.e., actual time frame) for evaluation and visualization purposes.

# %%
date_times = df.index.values

# %% [markdown]
# Load features from the dataframe, and normalize between 0-1.
# This scaler *object* is the min max scaler, which can be used to inverse the scale after prediction.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# Scale the dataset using the min-max scaler object.

# %%
values = df.values.astype('float32')
scaled_values = scaler.fit_transform(values)

# %% [markdown]
# ### Format to adapt recurrent learning

# %% [markdown]
# Define how many time intervals is required/used to predict the energy consumption.
# * For this experiment, we take 6 hours of previous energy consumption (i.e., six 1-hour intervals) - used as *n_1hour_interval*
# * Define the number of feature columns in order to construct data records combining sequence of *n_1hour_interval* s

# %%
n_1hour_interval = 6
n_features = df.shape[1]

# %% [markdown]
# The following function will enable to construct input records capturing more than 1 hour of input time steps.
# This is one of the most important pre-processing steps to use Backpropagation through time by recurrent neural networks when learning sequence predictions problems.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
df_reframed = series_to_supervised(scaled_values, n_1hour_interval, 1)

# %%
df_reframed.head()
# Out:
#     var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 6    0.206663   0.274741   0.277736   0.275346   0.283437   0.277141  0.264538
# 7    0.274741   0.277736   0.275346   0.283437   0.277141   0.264538  0.484091
# 8    0.277736   0.275346   0.283437   0.277141   0.264538   0.484091  0.553379
# 9    0.275346   0.283437   0.277141   0.264538   0.484091   0.553379  0.552784
# 10   0.283437   0.277141   0.264538   0.484091   0.553379   0.552784  0.554886

# %% [markdown]
# ### Train-Test split
#
# Split the dataset into train set and test set.
# First *n_obs* parametarized number of feature columns in the dataset.

# %%
n_obs = n_1hour_interval * n_features
n_obs
# Out:
# 6

# %% [markdown]
# For this experiment we use 70/30 train/test split.

# %%
n_train_records = int(len(df_reframed.values) * .7) 
n_train_records
# Out:
# 6127

# %% [markdown]
# Split the dataset for training and testing.

# %%
train = df_reframed.values[:n_train_records, :]
test = df_reframed.values[n_train_records:, :]
test_date_times = date_times[n_train_records:]
print('Train shape:', train.shape)
print('Test shape:', test.shape)
# Out:
# Train shape: (6127, 7)
# Test shape: (2627, 7)

# %% [markdown]
# Construct X set as the features and Y set as the predictor/ or the output variable.

# %%
X_train, y_train = train[:, :n_obs], train[:, -1]  
X_test, y_test = test[:, :n_obs], test[:, -1]
print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('\nX_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (6127, 6)
# y_train shape: (6127,)
#
# X_test shape: (2627, 6)
# y_test shape: (2627,)

# %% [markdown]
# The inputs (X) are reshaped into the 3D format expected by RNN, namely (samples, timesteps, features).

# %%
X_train = X_train.reshape((X_train.shape[0], n_1hour_interval, n_features))
X_test = X_test.reshape((X_test.shape[0], n_1hour_interval, n_features))
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
# Out:
# X_train shape: (6127, 6, 1)
# X_test shape: (2627, 6, 1)

# %% [markdown]
# ## Modelling
#
# We design a RNN based on hierarchically stacked three layered LSTM network architecture that consists of 32, 24 and 12 LSTM Networks respectively, accommodating deeper abstraction of temporal hierarchy to be trained by the forecasting model.

# %% [markdown]
# Model design:

# %%
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(24, return_sequences=True))
model.add(LSTM(12))
model.add(Dense(1))

# %% [markdown]
# Compile the model with [Mean Squarred Error](https://keras.io/losses/) loss functions and [ADAM optimizer](https://keras.io/optimizers/).

# %%
model.compile(loss='mse', optimizer='adam')

# %% [markdown]
# Train the model with parameters;
# *   Train epochs: 50
# *   Batch size: 32
# *   Use 0.3 from the training dataset as model validation data.

# %%
train_epochs = 50
batch_size = 32
validation_split = 0.3
history = model.fit(X_train, y_train, epochs=train_epochs, batch_size=batch_size, validation_split=validation_split, verbose=1, shuffle=False)
# Out:
# Epoch 1/50
# 134/134 [==============================] - 11s 18ms/step - loss: 0.0577 - val_loss: 0.0369
# Epoch 2/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0345 - val_loss: 0.0299
# Epoch 3/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0204 - val_loss: 0.0097
# Epoch 4/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0103 - val_loss: 0.0085
# Epoch 5/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0095 - val_loss: 0.0077
# Epoch 6/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 7/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0081 - val_loss: 0.0065
# Epoch 8/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0073 - val_loss: 0.0058
# Epoch 9/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 10/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 11/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 12/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 13/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 14/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 15/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 16/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 17/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 18/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 19/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 20/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 21/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 22/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 23/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 24/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 25/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 26/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 27/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 28/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 29/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 30/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 31/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 32/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 33/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 34/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 35/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 36/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 37/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 38/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 39/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 40/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 41/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 42/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 43/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 44/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 45/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 46/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 47/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 48/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 49/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 50/50
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0027

# %% [markdown]
# Visualize the learning curve.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Make predictions using the trained RNN model for the X_test (test dataset.)

# %%
yhat = model.predict(X_test, batch_size=batch_size)
yhat.shape
# Out:
# (2627, 1)

# %% [markdown]
# Reshape the test dataset for calculations. (From 3D to 2D)

# %%
X_test = X_test.reshape((X_test.shape[0], n_1hour_interval * n_features))
X_test.shape
# Out:
# (2627, 6)

# %% [markdown]
# Evaluate the accuracy using root mean square error (RMSE)

# %%
mse = mean_squared_error(y_test, yhat)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.05748086

# %%
 X_test[:, -7:].shape
# Out:
# (2627, 6)

# %% [markdown]
# Rescale the predictions using the min-max scaler object.

# %%
inv_yhat = np.concatenate((yhat, X_test[:, -7:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]

# %% [markdown]
# Rescale the test data (y_test) using the min-max scaler object.

# %%
y_test = y_test.reshape((len(y_test), 1))
inv_y = np.concatenate((y_test, X_test[:, -7:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]

# %% [markdown]
# Get the rmse for actual prediction

# %%
mseActual = mean_squared_error(inv_yhat, inv_y)
rmseActual = np.sqrt(mseActual)
nrmseActual = rmseActual/np.mean(inv_y)
print("RMSE :", rmseActual)
print("NRMSE: ",nrmseActual)
# Out:
# RMSE : 5.9888735
# NRMSE:  0.11231839

# %% [markdown]
# Setup plot axes for prediction plot.

# %%
x_axis_labels = list(map(lambda x: pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S'), test_date_times[n_1hour_interval:]))

# %% [markdown]
# Plot the forecast with respect to actual energy consumption.

# %%
fig,ax = plt.subplots(figsize=(40,7))
ax.plot(x_axis_labels, inv_y, label='actual')
ax.plot(x_axis_labels, inv_yhat, label='predicted')
date_formatter = DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(date_formatter)
plt.gcf().autofmt_xdate()
plt.legend()
plt.ylabel('Energy Consumption (per 1 hour)')
plt.show()

# %% [markdown]
# Save the model

# %%
model.save("LSTM_model")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_model/assets
# INFO:tensorflow:Assets written to: LSTM_model/assets

# %% [markdown]
# ## Deployment
#
# We will deploy the trained model as a service using FastAPI

# %% [markdown]
# Install required packages

# %%
# !pip install colabcode
# !pip install fastapi
# !pip install  python-multipart
# Out:
# Collecting colabcode
#   Downloading colabcode-0.3.0-py3-none-any.whl (5.0 kB)
# Collecting nest-asyncio==1.4.3
#   Downloading nest_asyncio-1.4.3-py3-none-any.whl (5.3 kB)
# Collecting uvicorn==0.13.1
#   Downloading uvicorn-0.13.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.6 MB/s
# Collecting pyngrok>=5.0.0
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 9.4 MB/s
# Collecting jupyterlab==3.0.7
#   Downloading jupyterlab-3.0.7-py3-none-any.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 18.6 MB/s
# Collecting tornado>=6.1.0
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 43.2 MB/s
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab==3.0.7->colabcode) (4.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from jupyterlab==3.0.7->colabcode) (2.11.3)
# Collecting jupyter-server~=1.2
#   Downloading jupyter_server-1.10.2-py3-none-any.whl (392 kB)
#      |████████████████████████████████| 392 kB 49.7 MB/s
# Collecting jupyterlab-server~=2.0
#   Downloading jupyterlab_server-2.7.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from jupyterlab==3.0.7->colabcode) (21.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyterlab==3.0.7->colabcode) (5.5.0)
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from uvicorn==0.13.1->colabcode) (3.7.4.3)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Requirement already satisfied: click==7.* in /usr/local/lib/python3.7/dist-packages (from uvicorn==0.13.1->colabcode) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.10->jupyterlab==3.0.7->colabcode) (2.0.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.8.0)
# Collecting requests-unixsocket
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.11.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.11.0)
# Collecting websocket-client
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (5.0.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (22.2.1)
# Collecting jupyter-client>=6.1.1
#   Downloading jupyter_client-7.0.2-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 39.4 MB/s
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (5.1.3)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.3.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.5 MB/s
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.2.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (21.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (5.6.1)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (2.10)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.1->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (2.8.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.1->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.3)
# Collecting jupyter-client>=6.1.1
#   Downloading jupyter_client-7.0.1-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 53.0 MB/s
#   Downloading jupyter_client-7.0.0-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 49.4 MB/s
#   Downloading jupyter_client-6.1.12-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 51.2 MB/s
# Collecting jsonschema>=3.0.1
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2.23.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2.9.1)
# Collecting json5
#   Downloading json5-0.9.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (21.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (4.6.4)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (57.4.0)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from nbclassic~=0.2->jupyterlab==3.0.7->colabcode) (5.3.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook<7->nbclassic~=0.2->jupyterlab==3.0.7->colabcode) (4.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok>=5.0.0->colabcode) (3.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (2.20)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2018.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (3.5.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.7.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyterlab==3.0.7->colabcode) (0.2.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (4.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->jupyterlab==3.0.7->colabcode) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2021.5.30)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=2c5934f7bfd3bef860a4fbf993e5bdfa76fda63822e7ad4ad61db5d42d911f90
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: tornado, jsonschema, sniffio, jupyter-client, websocket-client, requests-unixsocket, anyio, jupyter-server, json5, nbclassic, jupyterlab-server, h11, uvicorn, pyngrok, nest-asyncio, jupyterlab, colabcode
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# Successfully installed anyio-3.3.0 colabcode-0.3.0 h11-0.12.0 json5-0.9.6 jsonschema-3.2.0 jupyter-client-6.1.12 jupyter-server-1.10.2 jupyterlab-3.0.7 jupyterlab-server-2.7.2 nbclassic-0.3.1 nest-asyncio-1.4.3 pyngrok-5.1.0 requests-unixsocket-0.2.0 sniffio-1.2.0 tornado-6.1 uvicorn-0.13.1 websocket-client-1.2.1
# Collecting fastapi
#   Downloading fastapi-0.68.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 785 kB/s
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 9.9 MB/s
# Collecting starlette==0.14.2
#   Downloading starlette-0.14.2-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 6.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi) (3.7.4.3)
# Installing collected packages: starlette, pydantic, fastapi
# Successfully installed fastapi-0.68.1 pydantic-1.8.2 starlette-0.14.2
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from python-multipart) (1.15.0)
# Building wheels for collected packages: python-multipart
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=09d0798634b5afbb0738231c9d2ea1742084b95a505b13c1fc10bec349c2bd38
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
# Successfully built python-multipart
# Installing collected packages: python-multipart
# Successfully installed python-multipart-0.0.5

# %%
# import required packages
from typing import Optional

from fastapi import FastAPI, File, UploadFile
from fastapi.middleware.cors import CORSMiddleware
from io import BytesIO
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# %% [markdown]
# Crete Fast API app instance

# %%
app = FastAPI()
app.add_middleware(
    CORSMiddleware,
    allow_origins=['*'],
    allow_credentials=True,
    allow_methods=['*'],
    allow_headers=['*'],
)

# %%
# %%writefile models.py
from pydantic import BaseModel, conlist
from typing import List


class LSTM(BaseModel):
    data: List[conlist(float, min_items=6, max_items=6)]
# Out:
# Writing models.py

# %%
from models import LSTM
@app.on_event("startup")
def load_pretrained_model():
    global model
    model = load_model('LSTM_model')

@app.post("/predict/")
async def get_predictions(LSTM: LSTM):
    data = dict(LSTM)['data']
    data=np.array(data)
    data=data.reshape(n_1hour_interval,-1)
    scaledData =scaler.transform(data)
    input = scaledData.flatten().reshape((1, n_1hour_interval, n_features))
    output=model.predict(input)
    output=scaler.inverse_transform(output)
    finalOut=str(output[0][0])
    return {"status":1,"Prediction": finalOut}

# %% [markdown]
# We will use ColabCode library to depoly the FastAPI app inside the colab Notebook

# %%
from colabcode import ColabCode
server = ColabCode(port=10000, code=False)

# %% [markdown]
# Run the server
#
# Visit the UI using the Public URL generated.
#
# e.g. https://PublicURL/docs/

# %%
server.run_app(app=app)
# Out:
# Public URL: NgrokTunnel: "https://03a3-34-67-92-199.ngrok.io" -> "http://localhost:10000"

# %% [markdown]
# Sample data to try out ;
#
# *   Input  : 65.187, 72.062, 86.312, 89.437, 91.063, 96.561
# *   Intended Output :  95.062
